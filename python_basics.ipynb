# %%
#comments 
# use # for single line comments 
""" 
use this 
for 
multi line comments
"""

# %%
#Type inference 
age = 32
type(age)
print(type(age))
# Out:
# <class 'int'>

# %%
#Example 
# problem on indentation
if True:
    print("Correct indentation")
    if False :
        print ('This on to print')
    print("This will print")
print('Outside the if block')
# Out:
# Correct indentation
# This will print
# Outside the if block

# %%
name = "Kamakshi"
Name = "Gupta"

print(name) 
print(Name)
#Case sensitivity - python is case sensitive
# Out:
# Kamakshi
# Gupta

# %%
#Line continuation
total = 1+2+3+4+5+6+7+\
4+5+6
print(total)
# Out:
# 43

# %%
#Multiple statement on a single line
x = 5 ; y =10; z = x+y
print(z)
# Out:
# 15

# %%
#Indentation 
age = 32 
if age > 30:
    print(age)
print(age)
# Out:
# 32
# 32
