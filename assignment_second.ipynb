# %%
#CONDITIONAL STATEMENT 
"""
 Q1. Positive, Negative or Zero
Write a Python program that takes an integer and prints:

Positive
Negative
Zero
"""
num = int(input("Enter a number :"))
if num>0:
    if num%2 ==0:
        print("number is even")
    else:
        print("number is odd")
    print("number is postive")
else:
    print("number is negative")

# %%
"""
 Q2. Even or Odd
Take an integer from the user and determine whether it is even or odd.
"""
num = int(input("Enter a number "))
if num%2 == 0:
    print("number is even")
else:
    print ("number is odd")

# %%
""" 
Q3. Voting Eligibility
Take age as input. Print Eligible if age is at least 18, otherwise print Not Eligible.
"""
age = int(input("enter age:"))
if age>18:
    print("eligible")
else:
    print("not eligible")

# %%
"""
 Q4. Largest of Two Numbers
Input two numbers and print the larger number.
"""
num1 = int(input('Enter a first number:'))
num2 =int(input('Enter a second number:'))
if num1>num2:
    print('num1 is greater than num2')
else:
    print('num2 is greater than num1')

# %%
""" 
Q5. Largest of Three Numbers
Input three numbers and find the largest using if-elif-else.
"""
num1 = int(input("Enter a first number"))
num2 = int(input('Enter a second number'))
num3 =int (input('Enter a third number'))

if num1>num2:
    print('num1 is largest number ')
elif num2>num3:
    print('num2 is largest number')
else:
    print('num3 is largest number')

# %%
""" Q6. Grade Calculator
Input marks and print:

90–100 → A
80–89 → B
70–79 → C
60–69 → D
Below 60 → F"""

marks = int(input("Enter a marks:"))
if 90<= marks <= 100:
    print("grade A")
elif 80<= marks <= 89:
    print('grade B')
elif 70<= marks <= 79:
    print('grade C')
elif 60 <= marks <= 69:
    print('grade D')
else:
    print('fail')

# %%
""" 
 Q8. Simple Calculator
Take two numbers and an operator (+, -, *, /) and
 perform the operation using conditional statements.
"""
num1 = int(input("Enter a number:"))
num2 = int(input("Enter a number"))
operator = input("Enter a operator +,-,*,/ :")

if operator == "+" :
    print(num1 + num2)
elif  operator == "-" :
    print(num1 - num2)
elif operator == "*" :
    print(num1*num2)
elif operator == "/":
    print(num1/num2)
else:
    print('Invalid operator')

# %%
# FOR LOOPS
"""
 Q9. Print 1 to N
Input N and print numbers from 1 to N using a for loop.
"""
n = int(input('Enter a number '))
for i in range(1,n+1):
    print(i)

# %%
""" 
 Q10. Print Even Numbers
Print all even numbers from 1 to 100.
"""
for i in range(1,101):
    if i%2 ==0:
       print(i)

# %%
"""
 Q11. Print Odd Numbers
Print all odd numbers from 1 to 100.
"""
for i in range (1,101):
    if i%2 !=0 :
        print(i)

# %%
"""
 Q12. Sum of N Numbers
Input N and calculate:

1 + 2 + 3 + ... + N 
"""
num = int(input("Enter a number:"))
sum=0
for i in range (1,n+1):
    sum = sum+i

print(sum)

# %%
""" 
Q14. Factorial
Input n and calculate n! using a for loop.
"""
num = int(input('Enter a number '))
mul = 1
for i in range (1,n+1):
    mul = mul*i
print(mul)

# %%
""" Q13. Multiplication Table
Input a number and print its multiplication table from 1 to 10.

"""
num = int(input('Enter a number:'))
for i in range (1,11):
    print(num*i)

# %%
"""
 Q15. Count Digits
Input an integer and count how many digits it contains.
"""
num = int(input('Enter a number'))
count = 0
for i in str(abs(num)):
    count = count+1
print("Number of digits:",count)

# %%
""" 
Q16. Sum of Digits
Input a number and calculate the sum of its digits.
"""
num = int(input('Enter a number'))
total = 0
for i in str(abs(num)):
    total = total+int(i)
print("Sum of digits:",total)

# %%
"""
Q17. Reverse a Number
Input an integer and reverse it using a loop.
"""
num = int(input("Enter a number:"))
for i in range(num,0,-1):
    print(i)

# %%
"""
 Q18. Prime Number
Write a program to check whether a number is prime.
"""
num = int(input('Enter a number:'))
if num <= 1:
    print("Not a prime number")
else:
    for i in range (2,num):
        if num%i == 0:
            print('Not a prime number')
            break
    else:
        print('Prime number')

# %%
#WHILE LOOP
"""
 Q19. Print 1 to N
Print numbers from 1 to N using a while loop.
"""
n = int(input("Enter a number:"))
count = 0
while count< n+1:
    print(count)
    count = count+1

# %%
""" 
Q20. Countdown
Input a number and print a countdown until 0.
"""
n = int(input('Enter a number'))
count = n
while count >= 0:
    print(count)
    count = count-1

# %%
""" 
Q22. Password System
Keep asking the user for a password until the correct password is entered.
"""
correct_passward = "python123"
passward = input("Enter a passward:")
while passward != correct_passward:
    print("Wrong passward.Try again.")
    passward = input("Enter a passward:")
print("correct passward! Access granted")

# %%
"""
Q23. Digit Sum Using while
Calculate the sum of digits of a number using a while loop.
"""
num = int(input("Enter a number :"))
sum = 0
while num>0:
    digit = num%10
    sum = sum+digit
    num = num//10
print("Sum of digit:",sum)

# %%
""" 
24. Number Reversal Using while
Reverse an integer using a while loop.
"""
num= int(input("Enter a number:"))
reverse = 0
while num> 0:
    digit = num%10
    reverse = reverse*10+digit
    num =num//10
print("Reversed number",reverse)

# %%
"""
Q25. Guess the Number
Create a number-guessing program that keeps asking until the user guesses the correct number.
"""
correct_number = "19082006"
guess_number = input("Enter a number :")
while guess_number != correct_number:
    print(" You guess a wrong number")
    guess_number = input("Enter a number:")
print("You guess the right number")

# %%
 # Nested loops and pattern problem
""" 
Q26. Square Pattern

For n = 5, print:

*****
*****
*****
*****
*****

"""

for i in range(5):
    for j in range(5):
        print("*",end="")
    print()

# %%
""" 
Q27. Increasing Star Pattern

*
**
***
****
*****
"""

for i in range(1,6):
    for j in range(i):
        print("*",end ="")
    print()

# %%
""" 
Q28. Number Pattern

1
12
123
1234
12345
"""

n = 2
for i in range(1,6):
    for j in range(i):
        print(j+1,end = "")
    print()

# %%
"""
Q29. Reverse Pattern

*****
****
***
**
*
"""
for i in range (5,0,-1):
    for j in range (i):
        print("*",end = "")
    print()

# %%
"""
Q30. Multiplication Tables
Print multiplication tables from 1 to 10 using nested loops.
"""
for i in range (1,11):
    for j in range (i):
        print(i*j,end = "")
    print()

# %%
##Mixed control flow
""" 
Q31. FizzBuzz
For numbers 1–100:

divisible by 3 → Fizz
divisible by 5 → Buzz
divisible by both → FizzBuzz
otherwise → number
"""
i = int(input("Enter a number"))
if i%3 == 0 and i% 5== 0:
        print("FizzBuzz")
elif i% 3 ==0:
        print("fizz")
elif i% 5 ==0:
            print("Buzz")
else:
         print(i)

# %%
""" 
Q32. Sum of Even and Odd Numbers
For numbers from 1 to N, calculate separately:

sum of even numbers
sum of odd numbers
"""

num = int(input("Enter a number:"))
even_sum = 0
odd_sum = 0
for i in range (1,num+1):
        if i % 2 == 0:
                even_sum = even_sum + i
        else:
                odd_sum = odd_sum + i
        
print('sum of even number',even_sum)
print("sum of odd number",odd_sum)
# Out:
# sum of even number 30
# sum of odd number 25

# %%
""" 
Q33. Prime Numbers from 1 to N
Input N and print all prime numbers from 1 to N.
"""

n = int(input('Enter a number'))
for num in range (2,n+1):
    is_prime = True
    for i in range (2,num):
        if num% i == 0:
            is_prime = False
            break
    if is_prime:
        print(num)
# Out:
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19

# %%
"""  
Q34. Armstrong Number
Check whether a given number is an Armstrong number.
"""
num = int(input("Enter a number:"))
original = num
digits = len(str(num))
sum = 0

while num>0:
    digit = num% 10
    sum = sum + digit**digits
    num = num//10

if sum == original:
    print("Armstrong number")
else:
    print("Not an Armstrong number")
# Out:
# Armstrong number

# %%
""" 
Q35. Palindrome Number
Check whether a number reads the same forward and backward.
"""
num = int(input("Enter a number"))
original = num
reverse = 0

while num>0:
    digit = num% 10
    reverse = reverse*10 + digit
    num = num//10

if reverse == original:
    print("Palindrome number")
else:
    print("Not a palindrome number")
# Out:
# Palindrome number
